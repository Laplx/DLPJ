# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import torch.nn.functional as F

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
torch.cuda.empty_cache()

# %%
# preprocess
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=128, shuffle=False, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class Bottleneck(nn.Module):
    expansion = 4
    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, planes * self.expansion, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(planes * self.expansion)
        
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes * self.expansion:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes * self.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes * self.expansion)
            )
    
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64
        
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)
    
    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)
    
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, out.size()[2:])
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def Net():
    return ResNet(Bottleneck, [3, 4, 6, 3])

# %%
model = Net().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100)

# %%
def train_model(num_epochs=100):
    model.train()
    for epoch in range(num_epochs):
        running_loss = 0.0
        for i, (images, labels) in enumerate(trainloader):
            images, labels = images.to(device), labels.to(device)
            
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            if (i + 1) % 100 == 0:
                print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}], Loss: {running_loss/100:.4f}')
                running_loss = 0.0
        scheduler.step()

# %%
def test_model():
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in testloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    print(f'Accuracy on test set: {100 * correct / total:.2f}%')

# %%
train_model(num_epochs=100)
# Out:
# Epoch [1/100], Step [100], Loss: 2.0374
# Epoch [1/100], Step [200], Loss: 1.5895
# Epoch [1/100], Step [300], Loss: 1.4052
# Epoch [2/100], Step [100], Loss: 1.1565
# Epoch [2/100], Step [200], Loss: 1.0829
# Epoch [2/100], Step [300], Loss: 1.0229
# Epoch [3/100], Step [100], Loss: 0.9220
# Epoch [3/100], Step [200], Loss: 0.8880
# Epoch [3/100], Step [300], Loss: 0.8483
# Epoch [4/100], Step [100], Loss: 0.7913
# Epoch [4/100], Step [200], Loss: 0.7424
# Epoch [4/100], Step [300], Loss: 0.7253
# Epoch [5/100], Step [100], Loss: 0.6717
# Epoch [5/100], Step [200], Loss: 0.6538
# Epoch [5/100], Step [300], Loss: 0.6503
# Epoch [6/100], Step [100], Loss: 0.5981
# Epoch [6/100], Step [200], Loss: 0.6073
# Epoch [6/100], Step [300], Loss: 0.5969
# Epoch [7/100], Step [100], Loss: 0.5438
# Epoch [7/100], Step [200], Loss: 0.5632
# Epoch [7/100], Step [300], Loss: 0.5484
# Epoch [8/100], Step [100], Loss: 0.4993
# Epoch [8/100], Step [200], Loss: 0.5247
# Epoch [8/100], Step [300], Loss: 0.5166
# Epoch [9/100], Step [100], Loss: 0.4846
# Epoch [9/100], Step [200], Loss: 0.4993
# Epoch [9/100], Step [300], Loss: 0.4821
# Epoch [10/100], Step [100], Loss: 0.4689
# Epoch [10/100], Step [200], Loss: 0.4704
# Epoch [10/100], Step [300], Loss: 0.4750
# Epoch [11/100], Step [100], Loss: 0.4405
# Epoch [11/100], Step [200], Loss: 0.4364
# Epoch [11/100], Step [300], Loss: 0.4485
# Epoch [12/100], Step [100], Loss: 0.4245
# Epoch [12/100], Step [200], Loss: 0.4229
# Epoch [12/100], Step [300], Loss: 0.4235
# Epoch [13/100], Step [100], Loss: 0.3922
# Epoch [13/100], Step [200], Loss: 0.4118
# Epoch [13/100], Step [300], Loss: 0.4118
# Epoch [14/100], Step [100], Loss: 0.3617
# Epoch [14/100], Step [200], Loss: 0.3959
# Epoch [14/100], Step [300], Loss: 0.3999
# Epoch [15/100], Step [100], Loss: 0.3532
# Epoch [15/100], Step [200], Loss: 0.3847
# Epoch [15/100], Step [300], Loss: 0.3779
# Epoch [16/100], Step [100], Loss: 0.3576
# Epoch [16/100], Step [200], Loss: 0.3709
# Epoch [16/100], Step [300], Loss: 0.3547
# Epoch [17/100], Step [100], Loss: 0.3342
# Epoch [17/100], Step [200], Loss: 0.3311
# Epoch [17/100], Step [300], Loss: 0.3352
# Epoch [18/100], Step [100], Loss: 0.3247
# Epoch [18/100], Step [200], Loss: 0.3290
# Epoch [18/100], Step [300], Loss: 0.3466
# Epoch [19/100], Step [100], Loss: 0.3029
# Epoch [19/100], Step [200], Loss: 0.3154
# Epoch [19/100], Step [300], Loss: 0.3241
# Epoch [20/100], Step [100], Loss: 0.2829
# Epoch [20/100], Step [200], Loss: 0.3018
# Epoch [20/100], Step [300], Loss: 0.3194
# Epoch [21/100], Step [100], Loss: 0.3001
# Epoch [21/100], Step [200], Loss: 0.2944
# Epoch [21/100], Step [300], Loss: 0.2928
# Epoch [22/100], Step [100], Loss: 0.2729
# Epoch [22/100], Step [200], Loss: 0.2840
# Epoch [22/100], Step [300], Loss: 0.2806
# Epoch [23/100], Step [100], Loss: 0.2832
# Epoch [23/100], Step [200], Loss: 0.2750
# Epoch [23/100], Step [300], Loss: 0.2816
# Epoch [24/100], Step [100], Loss: 0.2589
# Epoch [24/100], Step [200], Loss: 0.2732
# Epoch [24/100], Step [300], Loss: 0.2759
# Epoch [25/100], Step [100], Loss: 0.2471
# Epoch [25/100], Step [200], Loss: 0.2481
# Epoch [25/100], Step [300], Loss: 0.2667
# Epoch [26/100], Step [100], Loss: 0.2452
# Epoch [26/100], Step [200], Loss: 0.2425
# Epoch [26/100], Step [300], Loss: 0.2571
# Epoch [27/100], Step [100], Loss: 0.2409
# Epoch [27/100], Step [200], Loss: 0.2374
# Epoch [27/100], Step [300], Loss: 0.2522
# Epoch [28/100], Step [100], Loss: 0.2172
# Epoch [28/100], Step [200], Loss: 0.2399
# Epoch [28/100], Step [300], Loss: 0.2446
# Epoch [29/100], Step [100], Loss: 0.2150
# Epoch [29/100], Step [200], Loss: 0.2299
# Epoch [29/100], Step [300], Loss: 0.2294
# Epoch [30/100], Step [100], Loss: 0.1990
# Epoch [30/100], Step [200], Loss: 0.2105
# Epoch [30/100], Step [300], Loss: 0.2291
# Epoch [31/100], Step [100], Loss: 0.2052
# Epoch [31/100], Step [200], Loss: 0.2067
# Epoch [31/100], Step [300], Loss: 0.2224
# Epoch [32/100], Step [100], Loss: 0.1961
# Epoch [32/100], Step [200], Loss: 0.2058
# Epoch [32/100], Step [300], Loss: 0.2026
# Epoch [33/100], Step [100], Loss: 0.1895
# Epoch [33/100], Step [200], Loss: 0.2034
# Epoch [33/100], Step [300], Loss: 0.2060
# Epoch [34/100], Step [100], Loss: 0.1835
# Epoch [34/100], Step [200], Loss: 0.1825
# Epoch [34/100], Step [300], Loss: 0.2033
# Epoch [35/100], Step [100], Loss: 0.1737
# Epoch [35/100], Step [200], Loss: 0.1771
# Epoch [35/100], Step [300], Loss: 0.1886
# Epoch [36/100], Step [100], Loss: 0.1556
# Epoch [36/100], Step [200], Loss: 0.1817
# Epoch [36/100], Step [300], Loss: 0.1896
# Epoch [37/100], Step [100], Loss: 0.1615
# Epoch [37/100], Step [200], Loss: 0.1737
# Epoch [37/100], Step [300], Loss: 0.1692
# Epoch [38/100], Step [100], Loss: 0.1499
# Epoch [38/100], Step [200], Loss: 0.1604
# Epoch [38/100], Step [300], Loss: 0.1837
# Epoch [39/100], Step [100], Loss: 0.1497
# Epoch [39/100], Step [200], Loss: 0.1639
# Epoch [39/100], Step [300], Loss: 0.1656
# Epoch [40/100], Step [100], Loss: 0.1443
# Epoch [40/100], Step [200], Loss: 0.1652
# Epoch [40/100], Step [300], Loss: 0.1526
# Epoch [41/100], Step [100], Loss: 0.1351
# Epoch [41/100], Step [200], Loss: 0.1511
# Epoch [41/100], Step [300], Loss: 0.1547
# Epoch [42/100], Step [100], Loss: 0.1365
# Epoch [42/100], Step [200], Loss: 0.1406
# Epoch [42/100], Step [300], Loss: 0.1568
# Epoch [43/100], Step [100], Loss: 0.1227
# Epoch [43/100], Step [200], Loss: 0.1383
# Epoch [43/100], Step [300], Loss: 0.1498
# Epoch [44/100], Step [100], Loss: 0.1328
# Epoch [44/100], Step [200], Loss: 0.1203
# Epoch [44/100], Step [300], Loss: 0.1427
# Epoch [45/100], Step [100], Loss: 0.1215
# Epoch [45/100], Step [200], Loss: 0.1227
# Epoch [45/100], Step [300], Loss: 0.1407
# Epoch [46/100], Step [100], Loss: 0.1188
# Epoch [46/100], Step [200], Loss: 0.1266
# Epoch [46/100], Step [300], Loss: 0.1204
# Epoch [47/100], Step [100], Loss: 0.1221
# Epoch [47/100], Step [200], Loss: 0.1199
# Epoch [47/100], Step [300], Loss: 0.1232
# Epoch [48/100], Step [100], Loss: 0.1039
# Epoch [48/100], Step [200], Loss: 0.1070
# Epoch [48/100], Step [300], Loss: 0.1201
# Epoch [49/100], Step [100], Loss: 0.1125
# Epoch [49/100], Step [200], Loss: 0.1070
# Epoch [49/100], Step [300], Loss: 0.1098
# Epoch [50/100], Step [100], Loss: 0.0980
# Epoch [50/100], Step [200], Loss: 0.1062
# Epoch [50/100], Step [300], Loss: 0.1039
# Epoch [51/100], Step [100], Loss: 0.0910
# Epoch [51/100], Step [200], Loss: 0.1026
# Epoch [51/100], Step [300], Loss: 0.1135
# Epoch [52/100], Step [100], Loss: 0.0857
# Epoch [52/100], Step [200], Loss: 0.0870
# Epoch [52/100], Step [300], Loss: 0.1039
# Epoch [53/100], Step [100], Loss: 0.0858
# Epoch [53/100], Step [200], Loss: 0.0864
# Epoch [53/100], Step [300], Loss: 0.1074
# Epoch [54/100], Step [100], Loss: 0.0743
# Epoch [54/100], Step [200], Loss: 0.0832
# Epoch [54/100], Step [300], Loss: 0.0912
# Epoch [55/100], Step [100], Loss: 0.0753
# Epoch [55/100], Step [200], Loss: 0.0811
# Epoch [55/100], Step [300], Loss: 0.0872
# Epoch [56/100], Step [100], Loss: 0.0751
# Epoch [56/100], Step [200], Loss: 0.0773
# Epoch [56/100], Step [300], Loss: 0.0796
# Epoch [57/100], Step [100], Loss: 0.0680
# Epoch [57/100], Step [200], Loss: 0.0782
# Epoch [57/100], Step [300], Loss: 0.0743
# Epoch [58/100], Step [100], Loss: 0.0666
# Epoch [58/100], Step [200], Loss: 0.0669
# Epoch [58/100], Step [300], Loss: 0.0713
# Epoch [59/100], Step [100], Loss: 0.0641
# Epoch [59/100], Step [200], Loss: 0.0729
# Epoch [59/100], Step [300], Loss: 0.0728
# Epoch [60/100], Step [100], Loss: 0.0656
# Epoch [60/100], Step [200], Loss: 0.0601
# Epoch [60/100], Step [300], Loss: 0.0606
# Epoch [61/100], Step [100], Loss: 0.0521
# Epoch [61/100], Step [200], Loss: 0.0617
# Epoch [61/100], Step [300], Loss: 0.0587
# Epoch [62/100], Step [100], Loss: 0.0540
# Epoch [62/100], Step [200], Loss: 0.0542
# Epoch [62/100], Step [300], Loss: 0.0613
# Epoch [63/100], Step [100], Loss: 0.0510
# Epoch [63/100], Step [200], Loss: 0.0557
# Epoch [63/100], Step [300], Loss: 0.0540
# Epoch [64/100], Step [100], Loss: 0.0492
# Epoch [64/100], Step [200], Loss: 0.0460
# Epoch [64/100], Step [300], Loss: 0.0482
# Epoch [65/100], Step [100], Loss: 0.0444
# Epoch [65/100], Step [200], Loss: 0.0390
# Epoch [65/100], Step [300], Loss: 0.0429
# Epoch [66/100], Step [100], Loss: 0.0405
# Epoch [66/100], Step [200], Loss: 0.0381
# Epoch [66/100], Step [300], Loss: 0.0456
# Epoch [67/100], Step [100], Loss: 0.0468
# Epoch [67/100], Step [200], Loss: 0.0418
# Epoch [67/100], Step [300], Loss: 0.0396
# Epoch [68/100], Step [100], Loss: 0.0353
# Epoch [68/100], Step [200], Loss: 0.0358
# Epoch [68/100], Step [300], Loss: 0.0362
# Epoch [69/100], Step [100], Loss: 0.0297
# Epoch [69/100], Step [200], Loss: 0.0374
# Epoch [69/100], Step [300], Loss: 0.0382
# Epoch [70/100], Step [100], Loss: 0.0345
# Epoch [70/100], Step [200], Loss: 0.0327
# Epoch [70/100], Step [300], Loss: 0.0321
# Epoch [71/100], Step [100], Loss: 0.0255
# Epoch [71/100], Step [200], Loss: 0.0285
# Epoch [71/100], Step [300], Loss: 0.0349
# Epoch [72/100], Step [100], Loss: 0.0267
# Epoch [72/100], Step [200], Loss: 0.0250
# Epoch [72/100], Step [300], Loss: 0.0291
# Epoch [73/100], Step [100], Loss: 0.0245
# Epoch [73/100], Step [200], Loss: 0.0267
# Epoch [73/100], Step [300], Loss: 0.0229
# Epoch [74/100], Step [100], Loss: 0.0239
# Epoch [74/100], Step [200], Loss: 0.0247
# Epoch [74/100], Step [300], Loss: 0.0266
# Epoch [75/100], Step [100], Loss: 0.0238
# Epoch [75/100], Step [200], Loss: 0.0249
# Epoch [75/100], Step [300], Loss: 0.0232
# Epoch [76/100], Step [100], Loss: 0.0204
# Epoch [76/100], Step [200], Loss: 0.0211
# Epoch [76/100], Step [300], Loss: 0.0220
# Epoch [77/100], Step [100], Loss: 0.0167
# Epoch [77/100], Step [200], Loss: 0.0155
# Epoch [77/100], Step [300], Loss: 0.0202
# Epoch [78/100], Step [100], Loss: 0.0157
# Epoch [78/100], Step [200], Loss: 0.0174
# Epoch [78/100], Step [300], Loss: 0.0170
# Epoch [79/100], Step [100], Loss: 0.0143
# Epoch [79/100], Step [200], Loss: 0.0139
# Epoch [79/100], Step [300], Loss: 0.0145
# Epoch [80/100], Step [100], Loss: 0.0129
# Epoch [80/100], Step [200], Loss: 0.0158
# Epoch [80/100], Step [300], Loss: 0.0140
# Epoch [81/100], Step [100], Loss: 0.0123
# Epoch [81/100], Step [200], Loss: 0.0131
# Epoch [81/100], Step [300], Loss: 0.0135
# Epoch [82/100], Step [100], Loss: 0.0112
# Epoch [82/100], Step [200], Loss: 0.0091
# Epoch [82/100], Step [300], Loss: 0.0110
# Epoch [83/100], Step [100], Loss: 0.0091
# Epoch [83/100], Step [200], Loss: 0.0113
# Epoch [83/100], Step [300], Loss: 0.0134
# Epoch [84/100], Step [100], Loss: 0.0096
# Epoch [84/100], Step [200], Loss: 0.0099
# Epoch [84/100], Step [300], Loss: 0.0088
# Epoch [85/100], Step [100], Loss: 0.0083
# Epoch [85/100], Step [200], Loss: 0.0086
# Epoch [85/100], Step [300], Loss: 0.0080
# Epoch [86/100], Step [100], Loss: 0.0087
# Epoch [86/100], Step [200], Loss: 0.0096
# Epoch [86/100], Step [300], Loss: 0.0115
# Epoch [87/100], Step [100], Loss: 0.0080
# Epoch [87/100], Step [200], Loss: 0.0080
# Epoch [87/100], Step [300], Loss: 0.0088
# Epoch [88/100], Step [100], Loss: 0.0086
# Epoch [88/100], Step [200], Loss: 0.0071
# Epoch [88/100], Step [300], Loss: 0.0069
# Epoch [89/100], Step [100], Loss: 0.0059
# Epoch [89/100], Step [200], Loss: 0.0068
# Epoch [89/100], Step [300], Loss: 0.0059
# Epoch [90/100], Step [100], Loss: 0.0061
# Epoch [90/100], Step [200], Loss: 0.0063
# Epoch [90/100], Step [300], Loss: 0.0058
# Epoch [91/100], Step [100], Loss: 0.0054
# Epoch [91/100], Step [200], Loss: 0.0050
# Epoch [91/100], Step [300], Loss: 0.0065
# Epoch [92/100], Step [100], Loss: 0.0057
# Epoch [92/100], Step [200], Loss: 0.0053
# Epoch [92/100], Step [300], Loss: 0.0047
# Epoch [93/100], Step [100], Loss: 0.0064
# Epoch [93/100], Step [200], Loss: 0.0044
# Epoch [93/100], Step [300], Loss: 0.0058
# Epoch [94/100], Step [100], Loss: 0.0049
# Epoch [94/100], Step [200], Loss: 0.0052
# Epoch [94/100], Step [300], Loss: 0.0049
# Epoch [95/100], Step [100], Loss: 0.0042
# Epoch [95/100], Step [200], Loss: 0.0054
# Epoch [95/100], Step [300], Loss: 0.0052
# Epoch [96/100], Step [100], Loss: 0.0046
# Epoch [96/100], Step [200], Loss: 0.0047
# Epoch [96/100], Step [300], Loss: 0.0041
# Epoch [97/100], Step [100], Loss: 0.0047
# Epoch [97/100], Step [200], Loss: 0.0044
# Epoch [97/100], Step [300], Loss: 0.0047
# Epoch [98/100], Step [100], Loss: 0.0042
# Epoch [98/100], Step [200], Loss: 0.0041
# Epoch [98/100], Step [300], Loss: 0.0041
# Epoch [99/100], Step [100], Loss: 0.0040
# Epoch [99/100], Step [200], Loss: 0.0038
# Epoch [99/100], Step [300], Loss: 0.0052
# Epoch [100/100], Step [100], Loss: 0.0050
# Epoch [100/100], Step [200], Loss: 0.0042
# Epoch [100/100], Step [300], Loss: 0.0048

# %%
test_model()
# Out:
# Accuracy on test set: 93.97%

# %%
# save model
path = './models/best.pth'
torch.save(model.state_dict(), path)

# %%
# visualize the first convolutional layer's filters
import matplotlib.pyplot as plt
import numpy as np

def visualize_filters(model, save_path='filters_conv1.png'):
    # (out_channels, in_channels, kernel_size, kernel_size), [64, 3, 3, 3]
    weights = model.conv1.weight.data.cpu().numpy()
    
    weights = (weights - weights.min()) / (weights.max() - weights.min())

    fig, axes = plt.subplots(8, 8, figsize=(12, 12))
    for i in range(64):
        row = i // 8
        col = i % 8
        filter_img = weights[i].transpose(1, 2, 0)
        axes[row, col].imshow(filter_img)
        axes[row, col].axis('off')
    
    plt.tight_layout()
    plt.savefig(save_path)
    plt.close()
    print(f'Filter visualization saved to {save_path}')

# %%
# visualize loss landscape
from mpl_toolkits.mplot3d import Axes3D

def compute_loss(model, dataloader, criterion):
    model.eval()
    total_loss = 0.0
    total_samples = 0
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            total_loss += loss.item() * images.size(0)
            total_samples += images.size(0)
    return total_loss / total_samples

def visualize_loss_landscape(model, dataloader, criterion, save_path='loss_landscape.png'):
    model.eval()
    original_params = [p.clone().detach() for p in model.parameters()]
    
    # generate two random directions
    def normalize_direction(direction):
        norm = sum(torch.sum(d**2) for d in direction)**0.5
        return [d / norm for d in direction]
    
    direction1 = [torch.randn_like(p) for p in model.parameters()]
    direction2 = [torch.randn_like(p) for p in model.parameters()]
    direction1 = normalize_direction(direction1)
    direction2 = normalize_direction(direction2)
    
    grid_size = 20
    alpha = np.linspace(-1, 1, grid_size)
    beta = np.linspace(-1, 1, grid_size)
    losses = np.zeros((grid_size, grid_size))

    for i, a in enumerate(alpha):
        for j, b in enumerate(beta):
            for p, d1, d2, orig in zip(model.parameters(), direction1, direction2, original_params):
                p.data = orig + a * d1 + b * d2
            losses[i, j] = compute_loss(model, dataloader, criterion)

    for p, orig in zip(model.parameters(), original_params):
        p.data = orig

    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    X, Y = np.meshgrid(alpha, beta)
    surf = ax.plot_surface(X, Y, losses, cmap='viridis')
    ax.set_xlabel('Direction 1')
    ax.set_ylabel('Direction 2')
    ax.set_zlabel('Loss')
    ax.set_title('Loss Landscape')
    fig.colorbar(surf)
    plt.savefig(save_path)
    plt.close()
    print(f'Loss landscape saved to {save_path}')

# %%
# visualize interpretation using Grad-CAM
def visualize_grad_cam(model, dataloader, num_images=10, save_path='grad_cam.png'):
    model.eval()
    classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
    
    # register hook for layer4
    features = []
    gradients = []
    def save_features(module, input, output):
        features.append(output.detach())
    def save_gradients(module, grad_in, grad_out):
        gradients.append(grad_out[0].detach())
    
    model.layer4.register_forward_hook(save_features)
    model.layer4.register_backward_hook(save_gradients)
    
    images, labels = next(iter(dataloader))
    images, labels = images[:num_images].to(device), labels[:num_images].to(device)
    
    # original image
    inv_normalize = transforms.Normalize(
        mean=[-0.4914/0.2023, -0.4822/0.1994, -0.4465/0.2010],
        std=[1/0.2023, 1/0.1994, 1/0.2010]
    )
    
    fig, axes = plt.subplots(2, num_images, figsize=(num_images*2, 4))
    
    for i in range(num_images):
        img = images[i:i+1]
        label = labels[i].item()

        features.clear()
        gradients.clear()
        output = model(img)
        pred = output.argmax(dim=1).item()

        model.zero_grad()
        one_hot = torch.zeros_like(output)
        one_hot[0, label] = 1
        output.backward(gradient=one_hot)
  
        feature = features[0]  # [1, 2048, h, w]
        grad = gradients[0]    # [1, 2048, h, w]
        weights = torch.mean(grad, dim=(2, 3), keepdim=True)
        cam = torch.sum(weights * feature, dim=1, keepdim=True)
        cam = F.relu(cam)
        cam = cam - cam.min()
        cam = cam / cam.max()

        cam = F.interpolate(cam, size=(32, 32), mode='bilinear', align_corners=False)
        cam = cam[0, 0].cpu().numpy()

        img_display = inv_normalize(img[0]).permute(1, 2, 0).cpu().numpy()
        img_display = (img_display - img_display.min()) / (img_display.max() - img_display.min())
        axes[0, i].imshow(img_display)
        axes[0, i].set_title(f'Label: {classes[label]}\nPred: {classes[pred]}')
        axes[0, i].axis('off')

        axes[1, i].imshow(img_display)
        axes[1, i].imshow(cam, cmap='jet', alpha=0.5)
        axes[1, i].set_title('Grad-CAM')
        axes[1, i].axis('off')
    
    plt.tight_layout()
    plt.savefig(save_path)
    plt.close()
    print(f'Grad-CAM visualization saved to {save_path}')

# %%
visualize_filters(model)
visualize_loss_landscape(model, testloader, criterion)
visualize_grad_cam(model, testloader)
# Out:
# Filter visualization saved to filters_conv1.png
# Loss landscape saved to loss_landscape.png
# /data/miniconda/envs/torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1640: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# Grad-CAM visualization saved to grad_cam.png

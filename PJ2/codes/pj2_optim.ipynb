# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import torch.nn.functional as F

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
torch.cuda.empty_cache()

# %%
# preprocess
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=128, shuffle=False, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class Bottleneck(nn.Module):
    expansion = 4
    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, planes * self.expansion, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(planes * self.expansion)
        
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes * self.expansion:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes * self.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes * self.expansion)
            )
    
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64
        
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)
    
    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)
    
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, out.size()[2:])
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def Net():
    return ResNet(Bottleneck, [3, 4, 6, 3])

# %%
model = Net().to(device)
criterion = nn.CrossEntropyLoss()
# different optimizers
optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)
scheduler = optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.003, total_steps=100 * len(trainloader), pct_start=0.3)

# %%
def train_model(num_epochs=100, patience=10):
    model.train()
    best_acc = 0.0
    patience_counter = 0
    steps_per_epoch = len(trainloader)
    
    for epoch in range(num_epochs):
        running_loss = 0.0
        for i, (images, labels) in enumerate(trainloader):
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            scheduler.step()
            
            running_loss += loss.item()
            if (i + 1) % 100 == 0:
                print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}], Loss: {running_loss/100:.4f}')
                running_loss = 0.0

        # Early stopping
        acc = test_model()
        if acc > best_acc + 0.001:
            path = './models/resnet_optim.pth'
            torch.save(model.state_dict(), path)
            patience_counter = 0
        else:
            patience_counter += 1
            print(f'Patience counter: {patience_counter}/{patience}')
            if patience_counter >= patience:
                print(f'Early stopping at epoch {epoch+1}')
                break

# %%
def test_model():
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in testloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    acc = 100 * correct / total
    print(f'Accuracy on test set: {acc:.2f}%')
    return acc

# %%
train_model(num_epochs=100)
# Out:
# Epoch [1/100], Step [100], Loss: 1.3831
# Epoch [1/100], Step [200], Loss: 1.3197
# Epoch [1/100], Step [300], Loss: 1.2370
# Accuracy on test set: 58.57%
# Epoch [2/100], Step [100], Loss: 1.5204
# Epoch [2/100], Step [200], Loss: 1.3092
# Epoch [2/100], Step [300], Loss: 1.2373
# Accuracy on test set: 61.74%
# Epoch [3/100], Step [100], Loss: 1.1383
# Epoch [3/100], Step [200], Loss: 1.1827
# Epoch [3/100], Step [300], Loss: 1.0510
# Accuracy on test set: 65.34%
# Epoch [4/100], Step [100], Loss: 0.9929
# Epoch [4/100], Step [200], Loss: 0.9972
# Epoch [4/100], Step [300], Loss: 0.9959
# Accuracy on test set: 67.71%
# Epoch [5/100], Step [100], Loss: 0.9420
# Epoch [5/100], Step [200], Loss: 0.9149
# Epoch [5/100], Step [300], Loss: 0.9154
# Accuracy on test set: 71.45%
# Epoch [6/100], Step [100], Loss: 0.8711
# Epoch [6/100], Step [200], Loss: 0.8358
# Epoch [6/100], Step [300], Loss: 0.8423
# Accuracy on test set: 70.65%
# Epoch [7/100], Step [100], Loss: 0.8092
# Epoch [7/100], Step [200], Loss: 0.7606
# Epoch [7/100], Step [300], Loss: 0.7505
# Accuracy on test set: 73.93%
# Epoch [8/100], Step [100], Loss: 0.7210
# Epoch [8/100], Step [200], Loss: 0.7733
# Epoch [8/100], Step [300], Loss: 0.7593
# Accuracy on test set: 75.81%
# Epoch [9/100], Step [100], Loss: 0.6957
# Epoch [9/100], Step [200], Loss: 0.7339
# Epoch [9/100], Step [300], Loss: 0.7240
# Accuracy on test set: 76.13%
# Epoch [10/100], Step [100], Loss: 0.6997
# Epoch [10/100], Step [200], Loss: 0.7047
# Epoch [10/100], Step [300], Loss: 0.7340
# Accuracy on test set: 76.49%
# Epoch [11/100], Step [100], Loss: 0.7140
# Epoch [11/100], Step [200], Loss: 0.7227
# Epoch [11/100], Step [300], Loss: 0.7429
# Accuracy on test set: 77.10%
# Epoch [12/100], Step [100], Loss: 0.7252
# Epoch [12/100], Step [200], Loss: 0.7152
# Epoch [12/100], Step [300], Loss: 0.7341
# Accuracy on test set: 76.78%
# Epoch [13/100], Step [100], Loss: 0.7363
# Epoch [13/100], Step [200], Loss: 0.7384
# Epoch [13/100], Step [300], Loss: 0.7631
# Accuracy on test set: 72.33%
# Epoch [14/100], Step [100], Loss: 0.7561
# Epoch [14/100], Step [200], Loss: 0.7625
# Epoch [14/100], Step [300], Loss: 0.7834
# Accuracy on test set: 73.74%
# Epoch [15/100], Step [100], Loss: 0.7625
# Epoch [15/100], Step [200], Loss: 0.8028
# Epoch [15/100], Step [300], Loss: 0.8020
# Accuracy on test set: 73.96%
# Epoch [16/100], Step [100], Loss: 0.7805
# Epoch [16/100], Step [200], Loss: 0.7969
# Epoch [16/100], Step [300], Loss: 0.7822
# Accuracy on test set: 73.79%
# Epoch [17/100], Step [100], Loss: 0.7828
# Epoch [17/100], Step [200], Loss: 0.7779
# Epoch [17/100], Step [300], Loss: 0.8038
# Accuracy on test set: 71.34%
# Epoch [18/100], Step [100], Loss: 0.7955
# Epoch [18/100], Step [200], Loss: 0.7804
# Epoch [18/100], Step [300], Loss: 0.7642
# Accuracy on test set: 75.93%
# Epoch [19/100], Step [100], Loss: 0.7605
# Epoch [19/100], Step [200], Loss: 0.7336
# Epoch [19/100], Step [300], Loss: 0.7500
# Accuracy on test set: 75.17%
# Epoch [20/100], Step [100], Loss: 0.7387
# Epoch [20/100], Step [200], Loss: 0.7143
# Epoch [20/100], Step [300], Loss: 0.7371
# Accuracy on test set: 75.80%
# Epoch [21/100], Step [100], Loss: 0.6903
# Epoch [21/100], Step [200], Loss: 0.6990
# Epoch [21/100], Step [300], Loss: 0.6965
# Accuracy on test set: 75.46%
# Epoch [22/100], Step [100], Loss: 0.6892
# Epoch [22/100], Step [200], Loss: 0.6892
# Epoch [22/100], Step [300], Loss: 0.6588
# Accuracy on test set: 75.36%
# Epoch [23/100], Step [100], Loss: 0.6541
# Epoch [23/100], Step [200], Loss: 0.6393
# Epoch [23/100], Step [300], Loss: 0.6326
# Accuracy on test set: 79.43%
# Epoch [24/100], Step [100], Loss: 0.6368
# Epoch [24/100], Step [200], Loss: 0.6224
# Epoch [24/100], Step [300], Loss: 0.6002
# Accuracy on test set: 80.35%
# Epoch [25/100], Step [100], Loss: 0.6160
# Epoch [25/100], Step [200], Loss: 0.5875
# Epoch [25/100], Step [300], Loss: 0.6091
# Accuracy on test set: 80.28%
# Epoch [26/100], Step [100], Loss: 0.5764
# Epoch [26/100], Step [200], Loss: 0.5876
# Epoch [26/100], Step [300], Loss: 0.5674
# Accuracy on test set: 80.06%
# Epoch [27/100], Step [100], Loss: 0.5528
# Epoch [27/100], Step [200], Loss: 0.5657
# Epoch [27/100], Step [300], Loss: 0.5580
# Accuracy on test set: 78.37%
# Epoch [28/100], Step [100], Loss: 0.5233
# Epoch [28/100], Step [200], Loss: 0.5483
# Epoch [28/100], Step [300], Loss: 0.5410
# Accuracy on test set: 82.57%
# Epoch [29/100], Step [100], Loss: 0.5105
# Epoch [29/100], Step [200], Loss: 0.5198
# Epoch [29/100], Step [300], Loss: 0.5296
# Accuracy on test set: 81.94%
# Epoch [30/100], Step [100], Loss: 0.5076
# Epoch [30/100], Step [200], Loss: 0.4977
# Epoch [30/100], Step [300], Loss: 0.5017
# Accuracy on test set: 83.22%
# Epoch [31/100], Step [100], Loss: 0.4949
# Epoch [31/100], Step [200], Loss: 0.4768
# Epoch [31/100], Step [300], Loss: 0.5007
# Accuracy on test set: 80.81%
# Epoch [32/100], Step [100], Loss: 0.4559
# Epoch [32/100], Step [200], Loss: 0.4661
# Epoch [32/100], Step [300], Loss: 0.4897
# Accuracy on test set: 83.67%
# Epoch [33/100], Step [100], Loss: 0.4484
# Epoch [33/100], Step [200], Loss: 0.4713
# Epoch [33/100], Step [300], Loss: 0.4744
# Accuracy on test set: 82.65%
# Epoch [34/100], Step [100], Loss: 0.4620
# Epoch [34/100], Step [200], Loss: 0.4713
# Epoch [34/100], Step [300], Loss: 0.4558
# Accuracy on test set: 83.63%
# Epoch [35/100], Step [100], Loss: 0.4314
# Epoch [35/100], Step [200], Loss: 0.4372
# Epoch [35/100], Step [300], Loss: 0.4426
# Accuracy on test set: 83.14%
# Epoch [36/100], Step [100], Loss: 0.4285
# Epoch [36/100], Step [200], Loss: 0.4259
# Epoch [36/100], Step [300], Loss: 0.4371
# Accuracy on test set: 83.84%
# Epoch [37/100], Step [100], Loss: 0.4133
# Epoch [37/100], Step [200], Loss: 0.4170
# Epoch [37/100], Step [300], Loss: 0.4247
# Accuracy on test set: 84.79%
# Epoch [38/100], Step [100], Loss: 0.4050
# Epoch [38/100], Step [200], Loss: 0.3968
# Epoch [38/100], Step [300], Loss: 0.4104
# Accuracy on test set: 82.93%
# Epoch [39/100], Step [100], Loss: 0.4032
# Epoch [39/100], Step [200], Loss: 0.3910
# Epoch [39/100], Step [300], Loss: 0.3996
# Accuracy on test set: 85.05%
# Epoch [40/100], Step [100], Loss: 0.3892
# Epoch [40/100], Step [200], Loss: 0.3835
# Epoch [40/100], Step [300], Loss: 0.3943
# Accuracy on test set: 84.60%
# Epoch [41/100], Step [100], Loss: 0.3994
# Epoch [41/100], Step [200], Loss: 0.3745
# Epoch [41/100], Step [300], Loss: 0.3731
# Accuracy on test set: 85.75%
# Epoch [42/100], Step [100], Loss: 0.3701
# Epoch [42/100], Step [200], Loss: 0.3700
# Epoch [42/100], Step [300], Loss: 0.3648
# Accuracy on test set: 85.68%
# Epoch [43/100], Step [100], Loss: 0.3609
# Epoch [43/100], Step [200], Loss: 0.3420
# Epoch [43/100], Step [300], Loss: 0.3473
# Accuracy on test set: 86.10%
# Epoch [44/100], Step [100], Loss: 0.3409
# Epoch [44/100], Step [200], Loss: 0.3434
# Epoch [44/100], Step [300], Loss: 0.3527
# Accuracy on test set: 86.00%
# Epoch [45/100], Step [100], Loss: 0.3518
# Epoch [45/100], Step [200], Loss: 0.3280
# Epoch [45/100], Step [300], Loss: 0.3396
# Accuracy on test set: 86.83%
# Epoch [46/100], Step [100], Loss: 0.3276
# Epoch [46/100], Step [200], Loss: 0.3185
# Epoch [46/100], Step [300], Loss: 0.3362
# Accuracy on test set: 86.32%
# Epoch [47/100], Step [100], Loss: 0.3135
# Epoch [47/100], Step [200], Loss: 0.3321
# Epoch [47/100], Step [300], Loss: 0.3248
# Accuracy on test set: 87.10%
# Epoch [48/100], Step [100], Loss: 0.2934
# Epoch [48/100], Step [200], Loss: 0.3166
# Epoch [48/100], Step [300], Loss: 0.3263
# Accuracy on test set: 86.10%
# Epoch [49/100], Step [100], Loss: 0.2970
# Epoch [49/100], Step [200], Loss: 0.3045
# Epoch [49/100], Step [300], Loss: 0.3004
# Accuracy on test set: 86.23%
# Epoch [50/100], Step [100], Loss: 0.3046
# Epoch [50/100], Step [200], Loss: 0.2951
# Epoch [50/100], Step [300], Loss: 0.3011
# Accuracy on test set: 87.68%
# Epoch [51/100], Step [100], Loss: 0.2792
# Epoch [51/100], Step [200], Loss: 0.2789
# Epoch [51/100], Step [300], Loss: 0.2781
# Accuracy on test set: 87.70%
# Epoch [52/100], Step [100], Loss: 0.2604
# Epoch [52/100], Step [200], Loss: 0.2768
# Epoch [52/100], Step [300], Loss: 0.2830
# Accuracy on test set: 87.30%
# Epoch [53/100], Step [100], Loss: 0.2777
# Epoch [53/100], Step [200], Loss: 0.2796
# Epoch [53/100], Step [300], Loss: 0.2656
# Accuracy on test set: 87.80%
# Epoch [54/100], Step [100], Loss: 0.2625
# Epoch [54/100], Step [200], Loss: 0.2653
# Epoch [54/100], Step [300], Loss: 0.2721
# Accuracy on test set: 86.89%
# Epoch [55/100], Step [100], Loss: 0.2433
# Epoch [55/100], Step [200], Loss: 0.2466
# Epoch [55/100], Step [300], Loss: 0.2489
# Accuracy on test set: 87.98%
# Epoch [56/100], Step [100], Loss: 0.2442
# Epoch [56/100], Step [200], Loss: 0.2362
# Epoch [56/100], Step [300], Loss: 0.2428
# Accuracy on test set: 88.40%
# Epoch [57/100], Step [100], Loss: 0.2301
# Epoch [57/100], Step [200], Loss: 0.2242
# Epoch [57/100], Step [300], Loss: 0.2412
# Accuracy on test set: 88.70%
# Epoch [58/100], Step [100], Loss: 0.2280
# Epoch [58/100], Step [200], Loss: 0.2318
# Epoch [58/100], Step [300], Loss: 0.2411
# Accuracy on test set: 88.68%
# Epoch [59/100], Step [100], Loss: 0.2134
# Epoch [59/100], Step [200], Loss: 0.2209
# Epoch [59/100], Step [300], Loss: 0.2215
# Accuracy on test set: 89.33%
# Epoch [60/100], Step [100], Loss: 0.2051
# Epoch [60/100], Step [200], Loss: 0.2130
# Epoch [60/100], Step [300], Loss: 0.2105
# Accuracy on test set: 88.97%
# Epoch [61/100], Step [100], Loss: 0.1868
# Epoch [61/100], Step [200], Loss: 0.2111
# Epoch [61/100], Step [300], Loss: 0.1932
# Accuracy on test set: 89.47%
# Epoch [62/100], Step [100], Loss: 0.1944
# Epoch [62/100], Step [200], Loss: 0.1931
# Epoch [62/100], Step [300], Loss: 0.1893
# Accuracy on test set: 88.96%
# Epoch [63/100], Step [100], Loss: 0.1807
# Epoch [63/100], Step [200], Loss: 0.1793
# Epoch [63/100], Step [300], Loss: 0.1759
# Accuracy on test set: 89.38%
# Epoch [64/100], Step [100], Loss: 0.1722
# Epoch [64/100], Step [200], Loss: 0.1800
# Epoch [64/100], Step [300], Loss: 0.1724
# Accuracy on test set: 89.47%
# Epoch [65/100], Step [100], Loss: 0.1605
# Epoch [65/100], Step [200], Loss: 0.1800
# Epoch [65/100], Step [300], Loss: 0.1714
# Accuracy on test set: 89.74%
# Epoch [66/100], Step [100], Loss: 0.1537
# Epoch [66/100], Step [200], Loss: 0.1604
# Epoch [66/100], Step [300], Loss: 0.1625
# Accuracy on test set: 89.02%
# Epoch [67/100], Step [100], Loss: 0.1462
# Epoch [67/100], Step [200], Loss: 0.1418
# Epoch [67/100], Step [300], Loss: 0.1503
# Accuracy on test set: 89.84%
# Epoch [68/100], Step [100], Loss: 0.1576
# Epoch [68/100], Step [200], Loss: 0.1456
# Epoch [68/100], Step [300], Loss: 0.1480
# Accuracy on test set: 89.97%
# Epoch [69/100], Step [100], Loss: 0.1393
# Epoch [69/100], Step [200], Loss: 0.1300
# Epoch [69/100], Step [300], Loss: 0.1444
# Accuracy on test set: 90.29%
# Epoch [70/100], Step [100], Loss: 0.1207
# Epoch [70/100], Step [200], Loss: 0.1260
# Epoch [70/100], Step [300], Loss: 0.1249
# Accuracy on test set: 90.09%
# Epoch [71/100], Step [100], Loss: 0.1121
# Epoch [71/100], Step [200], Loss: 0.1258
# Epoch [71/100], Step [300], Loss: 0.1190
# Accuracy on test set: 90.74%
# Epoch [72/100], Step [100], Loss: 0.1097
# Epoch [72/100], Step [200], Loss: 0.1127
# Epoch [72/100], Step [300], Loss: 0.1082
# Accuracy on test set: 90.35%
# Epoch [73/100], Step [100], Loss: 0.1038
# Epoch [73/100], Step [200], Loss: 0.1000
# Epoch [73/100], Step [300], Loss: 0.1138
# Accuracy on test set: 90.64%
# Epoch [74/100], Step [100], Loss: 0.0855
# Epoch [74/100], Step [200], Loss: 0.0946
# Epoch [74/100], Step [300], Loss: 0.0960
# Accuracy on test set: 90.64%
# Epoch [75/100], Step [100], Loss: 0.0866
# Epoch [75/100], Step [200], Loss: 0.0902
# Epoch [75/100], Step [300], Loss: 0.0909
# Accuracy on test set: 90.38%
# Epoch [76/100], Step [100], Loss: 0.0770
# Epoch [76/100], Step [200], Loss: 0.0889
# Epoch [76/100], Step [300], Loss: 0.0827
# Accuracy on test set: 90.89%
# Epoch [77/100], Step [100], Loss: 0.0722
# Epoch [77/100], Step [200], Loss: 0.0812
# Epoch [77/100], Step [300], Loss: 0.0791
# Accuracy on test set: 91.02%
# Epoch [78/100], Step [100], Loss: 0.0624
# Epoch [78/100], Step [200], Loss: 0.0741
# Epoch [78/100], Step [300], Loss: 0.0736
# Accuracy on test set: 91.12%
# Epoch [79/100], Step [100], Loss: 0.0626
# Epoch [79/100], Step [200], Loss: 0.0650
# Epoch [79/100], Step [300], Loss: 0.0653
# Accuracy on test set: 91.04%
# Epoch [80/100], Step [100], Loss: 0.0586
# Epoch [80/100], Step [200], Loss: 0.0547
# Epoch [80/100], Step [300], Loss: 0.0643
# Accuracy on test set: 90.88%
# Epoch [81/100], Step [100], Loss: 0.0509
# Epoch [81/100], Step [200], Loss: 0.0573
# Epoch [81/100], Step [300], Loss: 0.0596
# Accuracy on test set: 91.31%
# Epoch [82/100], Step [100], Loss: 0.0475
# Epoch [82/100], Step [200], Loss: 0.0507
# Epoch [82/100], Step [300], Loss: 0.0579
# Accuracy on test set: 91.52%
# Epoch [83/100], Step [100], Loss: 0.0445
# Epoch [83/100], Step [200], Loss: 0.0433
# Epoch [83/100], Step [300], Loss: 0.0456
# Accuracy on test set: 91.44%
# Epoch [84/100], Step [100], Loss: 0.0453
# Epoch [84/100], Step [200], Loss: 0.0394
# Epoch [84/100], Step [300], Loss: 0.0426
# Accuracy on test set: 91.55%
# Epoch [85/100], Step [100], Loss: 0.0403
# Epoch [85/100], Step [200], Loss: 0.0397
# Epoch [85/100], Step [300], Loss: 0.0407
# Accuracy on test set: 91.56%
# Epoch [86/100], Step [100], Loss: 0.0386
# Epoch [86/100], Step [200], Loss: 0.0351
# Epoch [86/100], Step [300], Loss: 0.0406
# Accuracy on test set: 92.04%
# Epoch [87/100], Step [100], Loss: 0.0354
# Epoch [87/100], Step [200], Loss: 0.0348
# Epoch [87/100], Step [300], Loss: 0.0336
# Accuracy on test set: 91.61%
# Epoch [88/100], Step [100], Loss: 0.0312
# Epoch [88/100], Step [200], Loss: 0.0303
# Epoch [88/100], Step [300], Loss: 0.0328
# Accuracy on test set: 91.95%
# Epoch [89/100], Step [100], Loss: 0.0304
# Epoch [89/100], Step [200], Loss: 0.0316
# Epoch [89/100], Step [300], Loss: 0.0277
# Accuracy on test set: 91.94%
# Epoch [90/100], Step [100], Loss: 0.0266
# Epoch [90/100], Step [200], Loss: 0.0314
# Epoch [90/100], Step [300], Loss: 0.0271
# Accuracy on test set: 91.87%
# Epoch [91/100], Step [100], Loss: 0.0259
# Epoch [91/100], Step [200], Loss: 0.0258
# Epoch [91/100], Step [300], Loss: 0.0223
# Accuracy on test set: 91.77%
# Epoch [92/100], Step [100], Loss: 0.0223
# Epoch [92/100], Step [200], Loss: 0.0236
# Epoch [92/100], Step [300], Loss: 0.0221
# Accuracy on test set: 91.90%
# Epoch [93/100], Step [100], Loss: 0.0230
# Epoch [93/100], Step [200], Loss: 0.0238
# Epoch [93/100], Step [300], Loss: 0.0230
# Accuracy on test set: 91.97%
# Epoch [94/100], Step [100], Loss: 0.0211
# Epoch [94/100], Step [200], Loss: 0.0217
# Epoch [94/100], Step [300], Loss: 0.0233
# Accuracy on test set: 91.87%
# Epoch [95/100], Step [100], Loss: 0.0194
# Epoch [95/100], Step [200], Loss: 0.0219
# Epoch [95/100], Step [300], Loss: 0.0210
# Accuracy on test set: 91.95%
# Epoch [96/100], Step [100], Loss: 0.0186
# Epoch [96/100], Step [200], Loss: 0.0196
# Epoch [96/100], Step [300], Loss: 0.0200
# Accuracy on test set: 92.12%
# Epoch [97/100], Step [100], Loss: 0.0201
# Epoch [97/100], Step [200], Loss: 0.0200
# Epoch [97/100], Step [300], Loss: 0.0192
# Accuracy on test set: 92.11%
# Epoch [98/100], Step [100], Loss: 0.0215
# Epoch [98/100], Step [200], Loss: 0.0205
# Epoch [98/100], Step [300], Loss: 0.0201
# Accuracy on test set: 92.14%
# Epoch [99/100], Step [100], Loss: 0.0217
# Epoch [99/100], Step [200], Loss: 0.0202
# Epoch [99/100], Step [300], Loss: 0.0193
# Accuracy on test set: 92.14%
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 train_model(num_epochs=100)
#
# Cell In[8], line 19, in train_model(num_epochs, patience)
#      16 loss.backward()
#      17 optimizer.step()
# ---> 19 scheduler.step()
#      21 running_loss += loss.item()
#      22 if (i + 1) % 100 == 0:
#
# File /data/miniconda/envs/torch/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:230, in LRScheduler.step(self, epoch)
#     228 if epoch is None:
#     229     self.last_epoch += 1
# --> 230     values = self.get_lr()
#     231 else:
#     232     warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#
# File /data/miniconda/envs/torch/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:2087, in OneCycleLR.get_lr(self)
#    2084 step_num = self.last_epoch
#    2086 if step_num > self.total_steps:
# -> 2087     raise ValueError(
#    2088         f"Tried to step {step_num} times. The specified number of total steps is {self.total_steps}"  # noqa: UP032
#    2089     )
#    2091 for group in self.optimizer.param_groups:
#    2092     start_step = 0.0
#
# ValueError: Tried to step 39101 times. The specified number of total steps is 39100

# %%
test_model()
# Out:
# Accuracy on test set: 92.14%
# 92.14

# %%
# save model
path = './models/resnet_optim.pth'
torch.save(model.state_dict(), path)
